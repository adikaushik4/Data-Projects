# %%
# importing library modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf

# %% [markdown]
# ### Vectors

# %%
# Importing Dataframes for S&P 500 using Yfinance
df = yf.download('^GSPC',start='2017-01-01', auto_adjust=False)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price         Adj Close        Close         High          Low         Open  \
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC        ^GSPC
# Date
# 2017-01-03  2257.830078  2257.830078  2263.879883  2245.129883  2251.570068
# 2017-01-04  2270.750000  2270.750000  2272.820068  2261.600098  2261.600098
# 2017-01-05  2269.000000  2269.000000  2271.500000  2260.449951  2268.179932
# 2017-01-06  2276.979980  2276.979980  2282.100098  2264.060059  2271.139893
# 2017-01-09  2268.899902  2268.899902  2275.489990  2268.899902  2273.590088
# ...                 ...          ...          ...          ...          ...
# 2025-03-31  5611.850098  5611.850098  5627.560059  5488.729980  5527.910156
# 2025-04-01  5633.069824  5633.069824  5650.569824  5558.520020  5597.529785
# 2025-04-02  5670.970215  5670.970215  5695.310059  5571.479980  5580.759766
# ...

# %%
# Claculating the moving average
df['MA100'] = df['Close'].rolling(100).mean()

# %%
# 2. Generate position: 1 if Close > MA100, else 0
df['MA100'].dropna(inplace=True)
# Out:
# C:\Users\aditya\AppData\Local\Temp\ipykernel_23320\3285354807.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MA100'].dropna(inplace=True)

# %%
df.dropna(inplace=True)
df.head()
# Out:
# Price         Adj Close        Close         High          Low         Open  \
# Ticker            ^GSPC        ^GSPC        ^GSPC        ^GSPC        ^GSPC
# Date
# 2017-05-25  2415.070068  2415.070068  2418.709961  2408.010010  2409.540039
# 2017-05-26  2415.820068  2415.820068  2416.679932  2412.199951  2414.500000
# 2017-05-30  2412.909912  2412.909912  2415.260010  2409.429932  2411.669922
# 2017-05-31  2411.800049  2411.800049  2415.989990  2403.590088  2415.629883
# 2017-06-01  2430.060059  2430.060059  2430.060059  2413.540039  2415.649902
#
# Price           Volume        MA100
# Ticker           ^GSPC
# Date
# 2017-05-25  3538210000  2344.914888
# 2017-05-26  2806930000  2346.494788
# 2017-05-30  3205860000  2347.916387
# 2017-05-31  4518040000  2349.344387
# 2017-06-01  3860620000  2350.875188

# %%
df['price'] = df.Open.shift(-1).dropna(inplace=True)

# %%
mask = df['Close'] > df['MA100']
mask = mask.dropna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23320\468365221.py in ?()
# ----> 1 mask = df['Close'] > df['MA100']
#       2 mask = mask.dropna()
#
# c:\Users\aditya\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\common.py in ?(self, other)
#      72                     return NotImplemented
#      73
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#
# c:\Users\aditya\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py in ?(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#
# c:\Users\aditya\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, other, op)
# ...

# %%
mask = left > right
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23320\1758811212.py in ?()
# ----> 1 mask = left > right
#
# c:\Users\aditya\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\common.py in ?(self, other)
#      72                     return NotImplemented
#      73
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#
# c:\Users\aditya\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arraylike.py in ?(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#
# c:\Users\aditya\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, other, op)
#    7894     def _cmp_method(self, other, op):
# ...
